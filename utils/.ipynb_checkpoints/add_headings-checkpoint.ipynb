# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('../df/stories_last.csv')

# %%
df = df[(df['media_id'] <= 33) & (df['media_id'] > 0)].copy()
df = df[df['link'] == df['link']].copy()
df = df[df['link'] != '#'].copy()

# %%
# Sorry for this
def getHeading(_media_id, _link):
    url_parts = _link.split('/')

    # tg, vqh, lm        
    if _media_id in (19, 20, 25):
        return url_parts[1]
            
    # le temps
    elif _media_id == 21:
        if url_parts[1] == 'node':
            return 'longform'
        else:
            return url_parts[1]
    
    # le monde
    elif _media_id == 22:
        return url_parts[1]
    
    # rts info
    elif _media_id == 23:
        return url_parts[2]
    
    # mediapart
    elif _media_id == 26:
        return url_parts[2]
    
    # Libé
    elif _media_id == 28:
        if url_parts[1] in ['france', 'politiques']:
            return 'national'
        elif url_parts[1] == 'planete':
            return 'international'
        else:
            return url_parts[1]
    
    # 20 minutes
    elif _media_id == 24:
        if url_parts[2] != 'news':
            return url_parts[2]
            
        else:
            return url_parts[3]
        
    # le figaro (27): 3
    elif _media_id == 27:
        
        return url_parts[3]
    
    # La Côte, Le Nouvelliste, La Liberté
    elif _media_id in (29, 30, 31, 32):
        if url_parts[2] in ('valais', 'regions', 'canton'):
            return 'région'
        else:
            return url_parts[2]

    # Le Courrier    
    elif _media_id == 33:
        return ''
    
    else:
        print('Media', _media_id, 'not in list missing')
        return 'missing' + str(_media_id)

# %%
df['heading'] = ''
for i, row in df.iterrows():
    if row['media_id'] != 33: # Le Courrier: manuel
        df.at[i, 'heading'] = getHeading(row['media_id'], row['link'])
    else:
        # These headings get fixed right below
        print('C', end='')
# Out:
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCC

# %%
older_df = pd.read_csv('../df/stories_with_heading.csv')

# %%
older_df.tail()
# Out:
#           id                                              title  \
# 10488  23495      Région: les cultures ont souffert de la grêle
# 10489  23497       La Coquette, la buvette que tous attendaient
# 10490  23498  Malgré la sécheresse, cette eau qui tombe du ciel
# 10491  23499  Crash du Ju-52: les 20 victimes ont été retrou...
# 10492  23500           Quand le désir joue aux montagnes russes
#
#                                             absolute_url           time_start  \
# 10488  https://www.lacote.ch/articles/regions/distric...  2018-08-07 17:33:00
# 10489  https://www.lacote.ch/articles/regions/distric...  2018-08-07 17:45:00
# 10490  https://www.letemps.ch/suisse/malgre-secheress...  2018-08-07 17:54:00
# 10491  https://www.lematin.ch/faits-divers/crash-ju52...  2018-08-07 17:57:00
# 10492  https://www.lacote.ch/articles/lifestyle/sante...  2018-08-07 18:09:00
#
#                   time_end  minutes delta_str  \
# 10488  2018-08-07 17:45:00       12       12’
# 10489  2018-08-07 18:09:00       24       24’
# 10490                  NaN        0       NaN
# 10491                  NaN        0       NaN
# 10492                  NaN        0       NaN
#
#                                                     link  \
# 10488  /articles/regions/district-de-nyon/la-grele-a-...
# 10489  /articles/regions/district-de-morges/la-coquet...
# 10490     /suisse/malgre-secheresse-cette-eau-tombe-ciel
# 10491  /faits-divers/crash-ju52-20-victimes-retrouvee...
# 10492  /articles/lifestyle/sante/quand-le-desir-joue-...
#
#                          media  media_id  server_time          author  \
# 10488   https://www.lacote.ch/        29       0.0906             NaN
# 10489   https://www.lacote.ch/        29       0.1013    Sophie Zuber
# 10490   https://www.letemps.ch        21       0.0421  Aïna Skjellaug
# 10491  https://www.lematin.ch/        25       0.0893   Evelyne Emeri
# 10492   https://www.lacote.ch/        29       0.2578             NaN
#
#        story_time  agency  editor       heading  domains  paywall  hide
# 10488      0.0573       0       0        région      NaN        1     0
# 10489      0.0955       0       1        région      NaN        1     0
# 10490      0.0320       0       1        suisse      NaN        0     0
# 10491      0.1493       0       1  faits-divers      NaN        0     0
# 10492      0.0618       0       0     lifestyle      NaN        1     0

# %%
df[df['title'].str.contains('médailles suisses')]
# Out:
#          id                                              title  \
# 2581  23088  Les principales chances de médailles suisses à...
#
#                                            absolute_url           time_start  \
# 2581  https://www.tdg.ch/sports/actu/principales-cha...  2018-08-04 13:36:00
#
#                  time_end  minutes delta_str  \
# 2581  2018-08-04 13:57:00       21       21’
#
#                                                    link                media  \
# 2581  /sports/actu/principales-chances-medailles-sui...  https://www.tdg.ch/
#
#       media_id  server_time author  story_time  agency  editor heading  \
# 2581        19       0.1005    NaN       0.071       0       0  sports
#
#       domains  paywall  hide
# 2581      NaN        0     0

# %%
#df = df[df['id'] > 23088].copy()

# %%
df = older_df.append(df).copy()

# %%
# Add heading for Le Courrier
print("We’ll get {} missing headings for “Le Courrier”".format( df[(df['media_id'] == 33) & (df['heading'] == '')].shape[0]) )
# Out:
# We’ll get 29 missing headings for “Le Courrier”

# %%
for i, row in df[(df['media_id'] == 33) & (df['heading'] == '')].iterrows():
    print(row['absolute_url'])
    ua_headers = {'User-Agent': 'Quel-media-bot (+https://www.quel-media.com/about.html#robot)'}
    response = requests.get(row['absolute_url'], headers=ua_headers)
    if not response:
        print('Error loading', row['absolute_url'])
    elif response.status_code != 200:
        print('Error {} when loading {}'.format( response.status_code, row['url'] ) )
    doc = BeautifulSoup(response.content, 'html.parser')    
    tags = doc.select('.c-Article-theme .c-Article-breadcrumb-tagsLink')
    print(tags)
    if len(tags) > 0:
        tag = tags[0]
        print(tag.string, tag.get('href'))
        df.at[i, 'heading'] = tag.string
    else:
        print('No tag found')
    print()
# Out:
# https://lecourrier.ch/2018/08/06/sous-traitance-leffet-domino/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/geneve/">Genève</a>]
# Genève /theme/geneve/
#
# https://lecourrier.ch/2018/08/07/pf17-louverture-de-fontanet-saluee/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/geneve/">Genève</a>]
# Genève /theme/geneve/
#
# https://lecourrier.ch/2018/08/07/les-entendants-ne-sont-pas-a-lecoute/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/vaud/">Vaud</a>]
# Vaud /theme/vaud/
#
# https://lecourrier.ch/2018/08/08/cachotterie-au-sommet/
# [<a class="c-Article-breadcrumb-tagsLink" href="/rubrique/international/">International</a>]
# International /rubrique/international/
#
# https://lecourrier.ch/2018/08/07/les-entendants-ne-sont-pas-a-lecoute/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/vaud/">Vaud</a>]
# Vaud /theme/vaud/
#
# https://lecourrier.ch/2018/08/08/cachotterie-au-sommet/
# [<a class="c-Article-breadcrumb-tagsLink" href="/rubrique/international/">International</a>]
# International /rubrique/international/
#
# https://lecourrier.ch/2018/08/08/un-ete-sans-fetes-de-geneve/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/geneve/">Genève</a>]
# Genève /theme/geneve/
#
# https://lecourrier.ch/2018/08/09/les-syndicats-claquent-deja-la-porte/
# [<a class="c-Article-breadcrumb-tagsLink" href="/rubrique/suisse/">Suisse</a>]
# Suisse /rubrique/suisse/
#
# https://lecourrier.ch/2018/08/09/dessin-dun-clitoris-amendes-annulees/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/geneve/">Genève</a>]
# Genève /theme/geneve/
#
# https://lecourrier.ch/2018/08/09/locarno-au-feminin-pluriel/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/cinema/">Cinéma</a>]
# Cinéma /theme/cinema/
#
# https://lecourrier.ch/2018/08/09/le-rire-en-guise-de-stethoscope/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/vaud/">Vaud</a>]
# Vaud /theme/vaud/
#
# https://lecourrier.ch/2018/08/10/la-maison-uribe-vacille/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/solidarite/">Solidarité</a>]
# Solidarité /theme/solidarite/
#
# https://lecourrier.ch/2018/08/12/une-pratique-legitime-et-vitale/
# [<a class="c-Article-breadcrumb-tagsLink" href="/rubrique/societe/">Société</a>]
# Société /rubrique/societe/
#
# https://lecourrier.ch/2018/08/12/les-festivaliers-jouent-le-jeu-du-tri/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/vaud/">Vaud</a>]
# Vaud /theme/vaud/
#
# https://lecourrier.ch/2018/08/13/contre-les-violences-sexistes-une-loi/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/geneve/">Genève</a>]
# Genève /theme/geneve/
#
# https://lecourrier.ch/2018/08/13/le-rock150-grandeur-nature/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/valais/">Valais</a>]
# Valais /theme/valais/
#
# https://lecourrier.ch/2018/08/14/la-course-aux-livraisons/
# [<a class="c-Article-breadcrumb-tagsLink" href="/rubrique/international/">International</a>]
# International /rubrique/international/
#
# https://lecourrier.ch/2018/08/14/des-voisins-qui-derangent/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/geneve/">Genève</a>]
# Genève /theme/geneve/
#
# https://lecourrier.ch/2018/08/15/remedes-contre-lhomosexualite-mauro-poggia-diligente-une-enquete/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/geneve/">Genève</a>]
# Genève /theme/geneve/
#
# https://lecourrier.ch/2018/08/15/late-reclame-un-quai-des-bergues-pieton/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/geneve/">Genève</a>]
# Genève /theme/geneve/
#
# https://lecourrier.ch/2018/08/15/un-opera-a-partir-de-bribes-du-courrier/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/geneve/">Genève</a>]
# Genève /theme/geneve/
#
# https://lecourrier.ch/2018/08/15/et-la-suisse-fit-greve/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/scene/">Scène</a>]
# Scène /theme/scene/
#
# https://lecourrier.ch/2018/08/15/le-castrum-veut-reinvestir-yverdon/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/vaud/">Vaud</a>]
# Vaud /theme/vaud/
#
# https://lecourrier.ch/2018/08/16/yves-velan-un-art-du-roman/
# [<a class="c-Article-breadcrumb-tagsLink" href="/rubrique/culture/">Culture</a>]
# Culture /rubrique/culture/
#
# https://lecourrier.ch/2018/08/15/le-castrum-veut-reinvestir-yverdon/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/vaud/">Vaud</a>]
# Vaud /theme/vaud/
#
# https://lecourrier.ch/2018/08/16/respect-eternel/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/musique/">Musique</a>]
# Musique /theme/musique/
#
# https://lecourrier.ch/2018/08/16/lequateur-fragilise-les-femmes/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/solidarite/">Solidarité</a>]
# Solidarité /theme/solidarite/
#
# https://lecourrier.ch/2018/08/19/lausanne-veut-doper-son-tourisme/
# [<a class="c-Article-breadcrumb-tagsLink" href="/theme/vaud/">Vaud</a>]
# Vaud /theme/vaud/
#
# https://lecourrier.ch/2018/08/19/des-profits-sur-la-grece/
# [<a class="c-Article-breadcrumb-tagsLink" href="/rubrique/international/">International</a>]
# International /rubrique/international/

# %%
df[(df['media_id'] == 33) & (df['heading'] == '')]
# Out:
# Empty DataFrame
# Columns: [id, title, absolute_url, time_start, time_end, minutes, delta_str, link, media, media_id, server_time, author, story_time, agency, editor, heading, domains, paywall, hide]
# Index: []

# %%
df.shape
# Out:
# (12085, 19)

# %%
df.to_csv('../df/stories_with_heading.csv', index=False)
